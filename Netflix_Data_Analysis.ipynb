# %%
import pandas as pd
df = pd.read_csv("netflix_data.csv")
df.head()
# Out:
#     Title   Genre  Release_Year  Rating  Duration Country
# 0  Movie1   Drama          2020     7.5       120   India
# 1  Movie2  Action          2019     6.8       110     USA
# 2  Movie3  Comedy          2021     7.2       100      UK
# 3  Movie4   Drama          2018     8.0       130   India
# 4  Movie5  Action          2022     6.5       115     USA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         10 non-null     object
#  1   Genre         10 non-null     object
#  2   Release_Year  10 non-null     int64
#  3   Rating        10 non-null     float64
#  4   Duration      10 non-null     int64
#  5   Country       10 non-null     object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 612.0+ bytes

# %%
df.isnull().sum()
df.drop_duplicates(inplace=True)

# %%
df['Genre'].mode()
# Out:
# 0    Drama
# Name: Genre, dtype: object

# %%
df['Rating'].mean()
# Out:
# np.float64(7.44)

# %%
df['Country'].value_counts()
# Out:
# Country
# India     4
# USA       3
# UK        2
# Canada    1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

genre_counts = df['Genre'].value_counts()
print(genre_counts)

genre_counts.plot(kind='bar')
plt.show()
# Out:
# Genre
# Drama     4
# Action    3
# Comedy    3
# Name: count, dtype: int64

# %%
plt.hist(df['Rating'])
plt.title("Rating Distribution")
plt.show()

# %%
df['Release_Year'].value_counts().sort_index().plot()
plt.title("Movies per Year")
plt.show()

# %%
df['Country'].value_counts().head().plot(kind='bar')
plt.title("Top Countries")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.title("Correlation Heatmap")
plt.show()
